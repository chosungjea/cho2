# %% [markdown]
# #과제05
#
# ###2016136128 조성재
#
#     -01. 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
#         -). 클래스와 모듈은 함수와 변수를 하나의 캡슐처럼 합쳐서 재사용하기 편하다는 공통점이 있다. 하지만 모듈은 파일내에 저장되면서 이름공간을 따로 사용할 수 있다는 장점이 있고 다른 사람과 파일을 공유하며 사용할 수 있다. 하지만 클래스는 모듈에 들어가는 부분집합같은 역할을 한다고 볼 수 있다.

# %% [markdown]
#     -02. 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %%
def add(a, b):
    return(a + b)

print(add(1, 2))
print(add('a', 'b'))
print(add([1,2], [3,4]))
# Out:
# 3
# ab
# [1, 2, 3, 4]

# %% [markdown]
#         -). 다형성이란 같은 구조의 코딩으로 다양한 기능을 수행할 수 있는 특징이다. 예를 들어 add함수를 정의하고 이를 단순히 1더하기2로 쓸 수도 있지만 문자열을 더할 수도 있고 게다가 배열을 더하여 하나로 합칠 수도 있다. 이를 이용하면 간결한 코드로 여러가지 기능을 수행하도록 만들 수 있다.

# %% [markdown]
#     -03. 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)
#
#         - 1) 요구사항 1. 생성자에 count 값과 step 값을 인자로 받을 수 있다.
#
#             count: Counter 인스턴스가 지니는 초기 정수 값
#             step: Counter 인스턴스의 count가 증가되는 증분 (defalt 값: 1)
#                 >>> c = Counter(10)
#                 >>> d = Counter(10, 2)
#
#         - 2) 요구사항 2. 다음과 같이 Counter의 인스턴스를 출력을 해주는 __str__() 메소드를 Counter 클래스 내에 구현하시오.
#
#             >>> print(c)
#             [Count (step: 1)] 10
#             >>> print(d)
#             [Count (step: 2)] 10
#
#         - 3) 요구사항 3. 다음과 같이 step에 주어진 증분만큼 count를 증가시키는 incr() 메소드를 Counter 클래스 내에 구현하시오.
#
#             >>> c.incr()
#             >>> d.incr()
#             >>> print(c)
#             [Count (step: 1)] 11
#             >>> print(d)
#             [Count (step: 2)] 12
#
#         - 4) 요구사항 4. Counter 클래스 내에 관련 메소드를 추가하여 인스턴스 객체를 직접 호출(call)할 수 있도록 하시오. 인스턴스 객체를 직접 호출했을 때에 내부적으로 incr() 메소드를 호출하는 방법으로 구현하시오.
#
#             >>> c()
#             >>> d()
#             >>> print(c)
#             [Count (step: 1)] 12
#             >>> print(d)
#             [Count (step: 2)] 14
#
#         - 5) 요구사항 5. 다음과 같은 두 개의 산술 연산 (+, -)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#
#             >>> c = c + 5
#             >>> d = d - 5
#             >>> print(c)
#             [Count (step: 1)] 17
#             >>> print(d)
#             [Count (step: 2)] 9
#
#         - 6) 요구사항 6. 다음과 같은 관계연산 (>, <, ==)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#
#             >>> print(c) > 10
#             True
#             >>> print(d) > 10
#             False
#             >>> print(c) < 10
#             False
#             >>> print(d) < 10
#             True
#             >>> print(c) == 17
#             True
#             >>> print(d) != 9
#             False

# %%
class Counter:
    def __init__(self, count, step=1):
        self.count = count
        self.step = step
    def __str__(self):
        return '[Count (step: %d)] %d' % (self.step, self.count)
    def incr(self):
        self.count = self.step + self.count
    def __call__(self):
        self.incr()
    def __add__(self, other):
        self.count = other + self.count
        return self.count
    def __sub__(self, other):
        self.count = self.count - other
        return self.count
    def __gt__(self, k):
        return self.count > k
    def __lt__(self, k):
        return self.count < k
    def __eq__(self, k):
        return self.count == k
    def __ne__(self, k):
        return self.count != k

# %%
c = Counter(10)
d = Counter(10, 2)
print(c)
print(d)
c.incr()
d.incr()
print(c)
print(d)
c()
d()
print(c)
print(d)
c = c + 5
d = d - 5
print(c)
print(d)
print(c > 10)
print(d > 10)
print(c < 10)
print(d < 10)
print(c == 17)
print(d != 9)
# Out:
# [Count (step: 1)] 10
# [Count (step: 2)] 10
# [Count (step: 1)] 11
# [Count (step: 2)] 12
# [Count (step: 1)] 12
# [Count (step: 2)] 14
# 17
# 9
# True
# False
# False
# True
# True
# False

# %% [markdown]
#         -). 클래스에 매소드와 연산자 중복을 사용하여 잘 작동하는지 확인해보았다. 메소드에 self를 반드시 넣어야 작동한다는 것을 알았다. 그 외에는 수업시간에 했던 것들이였다.

# %% [markdown]
#     -04. 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스정의 내용이다. 다음 클래스 정의에서 __init__(), __str()__(), elimicate_duplicate()의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.
#
#         -1) MySet은 집합(Set) 자료형을 정의하려는 의도하에 만들어진 클래스이다.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print(s)
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print(t)
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %% [markdown]
#         -). 먼저 __init__함수는 처음 클래스의 객체가 정의될 때 자동으로 사용되는 매소드로 보통 처음에 설정할 것이 있을 때 쓰이는 매소드이다. 다음으로 __str__함수는 클래스 외부 즉 메인에서 print를 사용하면 불리는 매소드로 보통 무엇을 호출할 때 쓰이는 기능이다. 마지막으로 micate_duplicate()함수는 집합 자료형을 넘겨받고 이를 하나씩 s에 추가하는데 만약 중복되는 것이 있으면 이는 추가하지 않아서 자동적으로 중복을 제거하도록 했다. 이를 다시 l에다가 빈 배열을 넣고 차례로 하나씩 추가하도록 하여 원래 배열에 중복을 없앤 것으로 바꾸는 매소드를 만들었다.

# %% [markdown]
#     -05. 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오
#
#         - 정답을 각 요구사항별로 입력할 필요 없이 요구사항 3개 전체에 대해 1개의 MySet 클래스 정의 코드를 제시하고 주석등으로 해당 코드를 설명한다.
#         - 요구사항 1. | 연산으로 두 집합의 합집합을 반환한다.
#
#             >>> u = s | t
#             >>> print(u)
#             MySet: {1, 2, 3, 4, 5, 6, 7, 8, 9}
#
#         - 요구사항 2. & 연산으로 두 집합의 교집합을 반환한다.
#
#             >>> u = s & t
#             >>> print(u)
#             MySet: {2, 3}
#
#         - 요구사항 3. - 연산으로 두 집합의 차집합을 반환한다.
#
#             >>> s = MySet([1, 2, 3])
#             >>> t = MySet([3, 4, 5])
#             >>> u = s - t
#             >>> print(u)
#             MySet: {1, 2}

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
    def __or__(self, k):     #합집합을 구하는 매소드
        s = []
        for e in self:
            if e not in s:
                s.append(e)
                
        for e in k:
            if e not in s:
                s.append(e)
        
        j = []
        for e in s:
            j.append(e)
        return j
    
    def __and__(self, k):     #교집합을 구하는 매소드
        s = []
        for e in self:
            if e in k:
                if e not in s:
                    s.append(e)
        for e in k:
            if e in self:
                if e not in s:
                    s.append(e)
                    
        j = []
        for e in s:
            j.append(e)
        return j
    
    def __sub__(self, k):      #차집합을 구하는 매소드
        s = []
        for e in self:
            if e not in k:
                s.append(e)
        j = []
        for e in s:
            j.append(e)
        return j
    
    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)
    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print(s)
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print(t)
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %%
u = s | t
print(u)
u = s & t
print(u)
s = MySet([1, 2, 3]) 
t = MySet([3, 4, 5]) 
u = s - t 
print(u)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [2, 3]
# [1, 2]

# %% [markdown]
#         -). MySet 클래스를 수정하여 각각 합집합, 교집합 그리고 차집합을 수행하는 클래스를 만들었다. 합집합은 2개의 배열을 서로 중복만 없게 append를 이용하여 추가하면 되었다. 교집합은 먼저 앞의 배열을 확인하고 만약 뒤의 배열에 곂치는 것이 있으면 빈 리스트에 추가하고 다음에 뒤의 배열을 확인하여 앞의 배열과 곂치는 게 있으면 리스트에 추가하여 구했다. 마지막으로 차집합은 앞의 배열을 확인하고 이와 뒤의 배열이 곂치지 않은 것만 빈 리스트에 추가하여 구했다.

# %% [markdown]
#     -06. 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.
#
#         >>> s = MySet([1, 2, 3, 4, 5, 6])
#         >>> print(len(s))
#         > 6
#         >>> print(bool(s))
#         > True
#         >>> print(2 in s)
#         > True

# %%
s = MySet([1, 2, 3, 4, 5, 6])
print(len(s))
print(bool(s))
print(2 in s)
# Out:
# 6
# True
# True

# %% [markdown]
#         -). 우리가 __str__이나 __add__를 정의하여 print나 +기호를 쓸 수 있는 것처럼 in 은 처음부터 파이썬에서 정의된 기호이다. 따라서 in만 쓰더라도 앞뒤를 보고 파이썬은 알맞게 수행할 수 있다. 그리고 len이나 bool또한 처음부터 정의된 함수로 알맞은 매계변수를 넣어주면 작동하도록 코딩되어 우리가 편리하게 사용할 수 있다.

# %% [markdown]
#     -07. 이전 Assignment 3 (Assignment 4가 아님)의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하여 각 단어들에 대해 출현빈도를 사전형태({'world': 2, 'hello': 1, 'python': 1})로 저장하여 출력하는 것이었다. 이번에는 Assignment 3을 다시 확장/변형하여 다음과 같은 조건을 만족하도록 구현하시오.
#
#         1) 새로운 클래스 WebWordsFrequency를 정의하시오.
#             이전 Assignment 4에서 고려했던 pickle 모듈등은 전혀 고려하지 마시오.
#             즉, 하드디스크에 저장하고 다시 로드하는 기능은 본 숙제에는 배제하시오.
#             Assignment 4에서 고려했던 영어 불용어 처리는 적용하시오.
#
#         2) 생성자에 URL을 0개에서 임의의 개수를 넣을 수 있도록 생성자 인수를 가변인수로 정의하여 각각의 URL을 리스트 자료형에 유지하시오.
#             >>> w1 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com', 'https://www.amazon.com')
#             >>> w2 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com')
#             >>> w3 = WebWordsFrequency()
#
#         3) addUrl() 메소드를 구현하여 인스턴스를 생성한 이후에도 URL을 추가할 수 있도록 한다.
#
#             반드시 1개의 URL을 추가하도록 구현 (즉, 동시에 여러 개의 URL을 추가하는 것은 배제)
#             >>> w1.addUrl('https://github.com')
#             >>> w3.addUrl('http://stackoverflow.com')
#
#         4) removeUrl() 메소드를 구현하여 URL을 삭제할 수 있도록 한다.
#
#             반드시 1개의 URL을 삭제하도록 구현 (즉, 동시에 여러 개의 URL을 삭제하는 것은 배제)
#             >>> w1.removeUrl('http://www.cnn.com')
#             >>> w2.removeUrl('http://stackoverflow.com')
#
#         5) listUrls() 메소드를 구현하여 현재 등록된 모든 URL을 출력하는 기능을 추가
#             >>> w1.listUrls()
#             http://www.times.com
#             https://www.amazon.com
#             https://github.com
#
#         6) getWordsFrequency() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전을 반환하시오.
#
#             만약 등록된 URL이 없다면 공백 사전을 반환
#             >>> w1.getWordsFrequency()
#             {'hello': 8, 'site': 12, 'world': 2, 'science': 11, 'program': 1, 'python': 1}
#
#         7) getMaxFreqencyWords() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전에서 가장 많이 출현한 단어 리스트를 반환하시오.
#
#             >>> w1.getMaxFreqencyWords()
#             site
#
#             최다 출현 단어의 빈도수가 동일한 경우 모두 출력해주어야 함
#             >>> w2.getMaxFreqencyWords()
#             site
#             science
#             만약 등록된 URL이 없다면 None을 반환
#
#         8) 임의의 단어 1개를 파라미터로 받는 searchUrlByWord() 메소드를 구현하여 유사도가 높은 웹 사이트를 출력하시오.
#
#             >>> w1.searchUrlByWord("news")
#             http://www.cnn.com
#             파라미터로 받은 단어와 유사도가 동일한 URL이 여러 개이면 해당 URL을 모두 출력하시오.

# %%
# -*- coding:utf-8 -*-
from urllib import request 
import pickle

class WebWordsFrequency:
    siteUrl = []
    def __init__(self, *www):
        #siteUrl = []
        if len(www) > 0:
            for e in www:
                if e not in self.siteUrl:
                    self.siteUrl.append(e)
        else:
            pass
        
    def html_java_script_and_style_del(html_source):
        s1 = ""
        switch = False
        switch2 = 0
        start = 0
        end = 0
        for i in range(len(html_source)):
            if switch2 == False:
                html_source = html_source[:start] + (end - start)*" " + html_source[end:]
                switch2 = True
            if html_source[i] == '<':
                switch = True
                s1 = ""
            if switch == True:
                s1 = s1 + html_source[i]    
            if s1 == '<script' or s1 == '<style' :
                switch2 = True
                if s1 == '<script':
                    start = i-6
                else :
                    start = i-5
            if s1 == '</script' or s1 == '</style':
                switch2 =False
                if s1 == '</script':
                    end = i-7
                else :
                    end = i-6
            if html_source[i] == '>':
                switch = False
        return html_source

    def html_code_del(html_source):
        count = 0
        switch = 0
        for i in html_source:
            if i == '<':
                switch = True
            if switch == True:
                html_source = html_source[:count] + ' ' + html_source[count+1:]
            if i == '>':
                switch = False
            count = count + 1
        wordList = html_source.split()
        return wordList

    import string
    def punctuation_del(List):
        punctuationList = [string.punctuation[i] for i in range(len(string.punctuation))]
        for i in range(len(List)):
            for j in range(len(List[i])):
                for k in range(len(punctuationList)):
                    if List[i][j] == punctuationList[k]:
                        List[i] = List[i][:j] + " " + List[i][j+1:]
        List = " ".join(List)
        List = List.split()
        return List

    def same_string_num(List):
        listValue = []
        for i in range(len(List)):
            count = 0
            for j in range(len(List)):
                if List[i] == List[j]:
                    count = count + 1
            listValue.append(count)
        totalList = zip(List, listValue)
        return totalList


    #영어 불용어를 제거하는 함수
    def dict_del_stopWords(wordListForDict): 
        k = open('stopWords.txt', 'w')
        with open('stopWords.txt', 'r') as f: 
            stopWordList = f.read()
        stopLowWordList = stopWordList.split() 
        stopUpperWordList = list(map(Capitalize, stopLowWordList)) 
        for i in stopLowWordList:   
            if i in wordListForDict:
                del wordListForDict[i]
        for j in stopUpperWordList: 
            if j in wordListForDict:
                del wordListForDict[j]
        return wordListForDict

    def Capitalize(s): 
        return s.capitalize()
    
    #사전의 값을 정렬하여 가장 값이 큰 3개의 단어를 보여주는 함수
    def three_words_list(s): 
        s = s.items()
        s = sorted(s, key = element_2, reverse = True)
        List = [s[x][0] for x in range(3)] 
        return List
    #sorted함수의 정렬기준을 바꿀 함수
    def element_2(a):
        return a[1]
    #메인 함수
    def main_system(site_url): 
        url = site_url
        f = request.urlopen(url)
        source_bytes = f.read()
        source = source_bytes.decode('utf-8')
        html_source_save(site_url, source)
        source = source.strip()
        wordList = html_java_script_and_style_del(source)
        wordList = html_code_del(wordList)
        wordList = punctuation_del(wordList)
        wordListForDict= dict(same_string_num(wordList))
        wordListForDict = dict_del_stopWords(wordListForDict)
        pickling_dict_word(wordListForDict, url)
        return wordListForDict

    #단어를 검색하는 함수
    def searchRobot():
        word = input()
        count = 0 
        index = 0 
        similarity = {}
        nytimes = unpickling_dict_word('http://www.nytimes.com') 
        stackOverFlow = unpickling_dict_word('https://www.stackoverflow.com')
        nature = unpickling_dict_word('http://www.nature.com')
        steam  = unpickling_dict_word('http://store.steampowered.com')
        oxfam  = unpickling_dict_word('https://www.oxfam.org')

        siteList = [nytimes, stackOverFlow, nature, steam, oxfam]  
        #siteUrl = ['http://www.nytimes.com', 'https://www.stackoverflow.com',\
         #          'http://www.nature.com', 'http://store.steampowered.com', 'https://www.oxfam.org']
        for i in siteList:  
            for j in i:     
                if j.find(word) != -1:
                    count = count + i[j]
            similarity[siteUrl[index]] = count
            count = 0
            index = index + 1
        similarityList = sorted(similarity.items(), key = element_2, reverse = True) 
        for i in range(len(similarityList)): 
            print(similarityList[i][0])
            
    def addUrl(self, s):
        if s not in self.siteUrl:
            self.siteUrl.append(s)
            
    def removeUrl(self, s):
        k = []
        if s not in self.siteUrl:
            k.append(s)
        self.siteUrl = k
            
    def listUrls(self):
        for e in self.siteUrl:
            print(e)

# %%
w1 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com', 'https://www.amazon.com')
w1.addUrl('https://github.com')
#w1.removeUrl('http://www.cnn.com')
w1.listUrls()
# Out:
# http://www.cnn.com
# http://www.times.com
# https://www.amazon.com
# https://github.com

# %% [markdown]
#         느낀점: 일단 시험기간까지 과제가 어렵고 많아서 너무 힘들었다. 내일도 기말시험이 있는데 이 과제를 하고 있어야하는 현실이 괴롭다.
